# %%
# PYTHONPATH settings
import sys
sys.path.append("/home/jovyan/lib")

# %%
from mundilib import mundiCatalogue

# %% [markdown]
# ### opensearch 'Get' request example

# %%
c = mundiCatalogue()
S3 = c.getCollection("Sentinel3")

# %% [markdown]
# #### Launch an opensearch request on mundiCollection

# %%
#https://mundiwebservices.com/acdc/catalog/proxy/search/Sentinel3/opensearch?q=(onlineStatus:(ONLINE OR STAGING) 
#AND sensingStartDate:[2018-05-20T00:00:00Z TO 2018-05-20T23:59:59Z]&processingLevel=L1_)

from mundilib import mundiopenURL2

q = "q=(onlineStatus:(ONLINE OR STAGING) AND sensingStartDate:[2018-05-20T00:00:00Z TO 2018-05-20T23:59:59Z])&processingLevel=L1_"
response_wrapper_list = mundiopenURL2(S3, query=q)

# %% [markdown]
# #### Getting specific 'entry' field content

# %%
from mundilib import findentries
from mundilib import mundi_nsmap

entries = findentries(response_wrapper_list)
print (len(entries))
for entry in entries[:3]:
    node = entry.find("eo:processingDate", namespaces=mundi_nsmap)
    print (str(node.text))
    node = entry.find("eo:processingLevel", namespaces=mundi_nsmap)
    print (str(node.text))
# Out:
# 87
# 2018-06-14T23:44:06Z
# L1_
# 2018-06-14T23:44:04Z
# L1_
# 2018-06-14T23:34:10Z
# L1_

# %% [markdown]
# #### Display all 'opensearch' fields content from an entry

# %%
obj = entries[:1][0]
d = {}
for childNodes in obj:
    attr = str(childNodes.prefix) + ":" + childNodes.tag[childNodes.tag.index('}')+1:]
    d[attr] = childNodes.text

# list some attribute/value of the entry (panda table)
import pandas as pd
df = pd.DataFrame(d, index=['attribute value'])
pd.set_option('max_colwidth', 200)
df.T
# Out:
#                                                                                                                             attribute value
# None:id                                      S3A_SR_1_SRA_A__20180520T001502_20180520T010532_20180614T230017_3029_031_216______LN3_O_NT_003
# dc:identifier                                S3A_SR_1_SRA_A__20180520T001502_20180520T010532_20180614T230017_3029_031_216______LN3_O_NT_003
# None:summary                          name: S3A_SR_1_SRA_A__20180520T001502_20180520T010532_20180614T230017_3029_031_216______LN3_O_NT_003}
# None:category                                                                                                                       imagery
# eo:parentIdentifier                          S3A_SR_1_SRA_A__20180520T001502_20180520T010532_20180614T230017_3029_031_216______LN3_O_NT_003
# DIAS:metadataFormat                                                                                                                  NATIVE
# DIAS:imageFileFormat                                                                                                                 NETCDF
# DIAS:orderID                                                                                                                        UNKNOWN
# DIAS:sceneIndex                                                                                                                           1
# None:link                                                                                                                              None
# dc:date                                                                                                                2018-05-20T00:23:00Z
# None:title                                   S3A_SR_1_SRA_A__20180520T001502_20180520T010532_20180614T230017_3029_031_216______LN3_O_NT_003
# eo:sensorMode                                                                                                                            EO
# eo:instrument                                                                                                                          SRAL
# eo:productType                                                                                                                  SR_1_SRA_A_
# eo:processingLevel                                                                                                                      L1_
# eo:archivingCenter                                                                                                                    DIAS_
# eo:acquisitionStation                                                                                                                 ESAS3
# eo:processingDate                                                                                                      2018-06-14T23:44:06Z
# eo:productQualityStatus                                                                                                         NOTVERIFIED
# dc:creator                                                                                                                             dhus
# DIAS:productConfidentialityLevel                                                                                              NOT_PROTECTED
# DIAS:equivalentNumberofScene                                                                                                              1
# eo:platform                                                                                                                       Sentinel3
# dct:audience                                                                                                                            All
# DIAS:onlineStatus                                                                                                                    ONLINE
# DIAS:archiveInstanceReference                                                                                                         ACDC_
# DIAS:productDatapackSize                                                                                                      2.480343552E9
# None:published                                                                                                         2018-06-15T00:49:20Z
# None:updated                                                                                                           2018-06-16T00:03:49Z
# dc:format                                                                                                                              SAFE
# DIAS:cycleNumber                                                                                                                         31
# DIAS:pduDuration                                                                                                                       3029
# DIAS:passNumber                                                                                                                       23478
# DIAS:relativeOrbitDirection                                                                                                      DESCENDING
# DIAS:relativeOrbitNumber                                                                                                                216
# DIAS:relativePassNumber                                                                                                                 432
# DIAS:relativePassDirection                                                                                                       DESCENDING
# DIAS:landPercentage                                                                                                                    18.0
# DIAS:closedSeaPercentage                                                                                                                0.0
# DIAS:continentalIcePercentage                                                                                                          12.0
# DIAS:openSeaPercentage                                                                                                                 69.0
# DIAS:lrmPercentage                                                                                                                      0.0
# DIAS:sarPercentage                                                                                                                    100.0
# DIAS:manualQualityCheckStatus                                                                                                   NOT_CHECKED
# DIAS:manualQualityCheckStatusComment                                                                                            NOT_CHECKED
# DIAS:referenceProductOnly                                                                                                              true
# DIAS:sensingStartDate                                                                                                  2018-05-20T00:23:00Z
# DIAS:watcherRecordValidity                                                                                                            false
# DIAS:ingestionDate                                                                                                     2018-06-16T00:03:48Z
# DIAS:productDeliveryFormat                                                                                                              zip

# %%
from mundilib import mundinbopenURL2

q = "q=(onlineStatus:(ONLINE OR STAGING) AND sensingStartDate:[2018-05-20T00:00:00Z TO 2018-05-20T23:59:59Z])&processingLevel=L1_"
nb = mundinbopenURL2(S3, query=q)
print (nb)
# Out:
# 87
