# %%
# PYTHONPATH settings
import sys
sys.path.append("/home/jovyan/lib")

# %%
from mundilib import mundiCatalogue

# %%
# other tools
import pandas as pd

# %% [markdown]
# ### Data and metadata overview

# %%
c = mundiCatalogue()
csw = c.mundi_csw()

# %% [markdown]
# #### Current available collections in Mundi catalogue

# %%
from mundilib import mundiCatalogue
collections = c.getCollections()

for col in collections:
    print(col.name)
# Out:
# Landsat45
# Landsat7
# Landsat8
# Sentinel1
# Sentinel2
# Sentinel3

# %%
for col in collections:

    productTypes = col.productTypes()
    processingLevels = col.processingLevels()
    
    print ("\nMundi collection: ", col.name)

    for pt in productTypes:
        for pl in processingLevels:
            print ("%20s %20s %10s" % (col.name, pt.get('value'), pl.get('value')))
# Out:
# Mundi collection:  Landsat45
#            Landsat45                   T1       L1TP
#            Landsat45                   T1       L1GT
#            Landsat45                   T1       L1GS
#            Landsat45                   T2       L1TP
#            Landsat45                   T2       L1GT
#            Landsat45                   T2       L1GS
#            Landsat45                   RT       L1TP
#            Landsat45                   RT       L1GT
#            Landsat45                   RT       L1GS
#
# Mundi collection:  Landsat7
#             Landsat7                   T1       L1TP
#             Landsat7                   T1       L1GT
#             Landsat7                   T1       L1GS
#             Landsat7                   T2       L1TP
#             Landsat7                   T2       L1GT
#             Landsat7                   T2       L1GS
#             Landsat7                   RT       L1TP
#             Landsat7                   RT       L1GT
#             Landsat7                   RT       L1GS
#
# Mundi collection:  Landsat8
#             Landsat8                   T1       L1TP
#             Landsat8                   T1       L1GT
#             Landsat8                   T1       L1GS
#             Landsat8                   T2       L1TP
#             Landsat8                   T2       L1GT
#             Landsat8                   T2       L1GS
#             Landsat8                   RT       L1TP
#             Landsat8                   RT       L1GT
#             Landsat8                   RT       L1GS
#
# Mundi collection:  Sentinel1
#            Sentinel1                  RAW        L0_
#            Sentinel1                  RAW        L1_
#            Sentinel1                  RAW        L2_
#            Sentinel1                  OCN        L0_
#            Sentinel1                  OCN        L1_
#            Sentinel1                  OCN        L2_
#            Sentinel1                  GRD        L0_
#            Sentinel1                  GRD        L1_
#            Sentinel1                  GRD        L2_
#            Sentinel1                  SLC        L0_
#            Sentinel1                  SLC        L1_
#            Sentinel1                  SLC        L2_
#
# Mundi collection:  Sentinel2
#            Sentinel2                IMAGE        L1A
#            Sentinel2                IMAGE        L1B
#            Sentinel2                IMAGE        L1C
#            Sentinel2                IMAGE        L2A
#            Sentinel2             S2MSI2Ap        L1A
#            Sentinel2             S2MSI2Ap        L1B
#            Sentinel2             S2MSI2Ap        L1C
#            Sentinel2             S2MSI2Ap        L2A
#
# Mundi collection:  Sentinel3
#            Sentinel3          OL_1_EFR___        L1_
#            Sentinel3          OL_1_EFR___        L2_
#            Sentinel3          OL_1_ERR___        L1_
#            Sentinel3          OL_1_ERR___        L2_
#            Sentinel3          OL_2_WFR___        L1_
#            Sentinel3          OL_2_WFR___        L2_
#            Sentinel3          OL_2_WRR___        L1_
#            Sentinel3          OL_2_WRR___        L2_
#            Sentinel3          OL_2_LFR___        L1_
#            Sentinel3          OL_2_LFR___        L2_
#            Sentinel3          OL_2_LRR___        L1_
#            Sentinel3          OL_2_LRR___        L2_
#            Sentinel3          SR_1_SRA___        L1_
#            Sentinel3          SR_1_SRA___        L2_
#            Sentinel3          SR_1_SRA_A_        L1_
#            Sentinel3          SR_1_SRA_A_        L2_
#            Sentinel3          SR_1_SRA_BS        L1_
#            Sentinel3          SR_1_SRA_BS        L2_
#            Sentinel3          SR_2_WAT___        L1_
#            Sentinel3          SR_2_WAT___        L2_
#            Sentinel3          SR_2_LAN___        L1_
#            Sentinel3          SR_2_LAN___        L2_
#            Sentinel3          SL_1_RBT___        L1_
#            Sentinel3          SL_1_RBT___        L2_
#            Sentinel3          SL_2_WST___        L1_
#            Sentinel3          SL_2_WST___        L2_
#            Sentinel3          SL_2_LST___        L1_
#            Sentinel3          SL_2_LST___        L2_

# %% [markdown]
# #### Available metadata of collections (in table using pandas dataframe)

# %%
elems = {}
metadatas = []
for col in collections:
    col_elems = {}
    csw_col = c.getCollection(col.name).mundi_csw()
    col_elems = csw_col.mundidescriberecord()
    elems[col] = col_elems

# get unique metadata name
for key in elems:
    metadatas = set(m for m in elems[key])

# for each metadata, look if exist in collection
dict = {}
for metadata in sorted(metadatas):
    l = []
    for key in collections:
        if metadata in elems[key].keys():
            l.append ("x")
        else:
            l.append ("-")
    dict[metadata] = l
        
# print as table
names=set(n.name for n in collections)

df = pd.DataFrame(dict, index=names)
df.replace("\n","")
pd.set_option('display.expand_frame_repr', True)
pd.set_option('max_colwidth', 200)
pd.options.display.max_rows = 100
df.T
# Out:
#                                      Sentinel2 Sentinel3 Landsat8 Landsat7  \
# DIAS:acquisitionMode                         x         x        x        x
# DIAS:acquisitionOrbitNumber                  -         -        -        x
# DIAS:archiveCollection                       x         x        x        x
# DIAS:archiveCreationTimeStamp                x         x        x        x
# DIAS:archiveInstanceReference                x         x        x        x
# DIAS:archiveProductURI                       x         x        x        x
# DIAS:archiveUpdateTimeStamp                  x         x        x        x
# DIAS:archivingCenter                         x         x        x        x
# DIAS:checksum                                x         x        x        x
# DIAS:closedSeaPercentage                     -         -        -        -
# DIAS:cloudCoverPercentage                    x         x        x        -
# DIAS:coastalCoverPercentage                  -         -        -        -
# DIAS:continentalIcePercentage                -         -        -        -
# DIAS:cycleNumber                             -         -        -        -
# DIAS:ecmwf                                   -         -        -        -
# DIAS:equivalentNumberofScene                 x         x        x        x
# DIAS:externalUrls                            x         x        x        x
# DIAS:footprint                               x         x        x        x
# DIAS:freshWaterCoverPercentage               -         -        -        -
# DIAS:imageFileFormat                         x         x        x        x
# DIAS:incidenceAngle                          -         -        -        x
# DIAS:ingestionDate                           x         x        x        x
# DIAS:jobId                                   x         x        x        x
# DIAS:landPercentage                          -         -        -        -
# DIAS:lastOrbitNumber                         -         -        -        x
# DIAS:lastRelativeOrbitNumber                 -         -        -        x
# DIAS:leapSecond                              -         -        -        -
# DIAS:leapSecondOccurrence                    -         -        -        -
# DIAS:lrmPercentage                           -         -        -        -
# DIAS:manualQualityCheckStatus                x         x        x        x
# DIAS:manualQualityCheckStatusComment         x         x        x        x
# DIAS:metadataFormat                          x         x        x        x
# DIAS:metadataURI                             x         x        x        x
# DIAS:onlineDate                              x         x        x        x
# DIAS:onlineStatus                            x         x        x        x
# DIAS:openSeaPercentage                       -         -        -        -
# DIAS:orbitDirection                          x         x        x        x
# DIAS:orderID                                 x         x        x        x
# DIAS:passDirection                           -         -        -        -
# DIAS:passNumber                              -         -        -        -
# DIAS:pduAlongTrackCoord                      -         -        -        -
# DIAS:pduDuration                             -         -        -        -
# DIAS:polarisation                            -         -        -        x
# DIAS:processingBaseline                      -         -        -        x
# DIAS:processingCenter                        x         x        x        x
# DIAS:processingDate                          x         x        x        x
# DIAS:productConfidentialityLevel             x         x        x        x
# DIAS:productDatapackSize                     x         x        x        x
# DIAS:productDeliveryFormat                   x         x        x        x
# DIAS:productLevel                            x         x        x        x
# DIAS:productMarkedForDeletion                x         x        x        x
# DIAS:productType                             x         x        x        x
# DIAS:qualityQuotes                           x         x        x        x
# DIAS:quickLookURI                            x         x        x        x
# DIAS:receivingStation                        x         x        x        x
# DIAS:referencePoint                          x         x        x        x
# DIAS:referenceProductOnly                    x         x        x        x
# DIAS:relativeOrbitDirection                  -         -        -        -
# DIAS:relativeOrbitNumber                     -         -        -        x
# DIAS:relativePassDirection                   -         -        -        -
# DIAS:relativePassNumber                      -         -        -        -
# DIAS:resolution                              x         x        x        x
# DIAS:salineWaterCoverPercentage              -         -        -        -
# DIAS:sarPercentage                           -         -        -        -
# DIAS:sceneIndex                              x         x        x        x
# DIAS:sensingStartDate                        x         x        x        x
# DIAS:sensingStopDate                         x         x        x        x
# DIAS:sensorFamily                            x         x        x        x
# DIAS:sensorMode                              x         x        x        x
# DIAS:snowCoverPercentage                     -         -        -        -
# DIAS:sourceStripID                           x         x        x        x
# DIAS:startOrbitNumber                        -         -        -        x
# DIAS:thumbnailURI                            x         x        x        x
# DIAS:tidalRegionCoverPercentage              -         -        -        -
# DIAS:timelinessCategory                      x         x        x        x
# DIAS:uuid                                    x         x        x        x
# DIAS:watcherRecordValidity                   x         x        x        x
# ows:BoundingBox                              x         x        x        x
#
#                                      Sentinel1 Landsat45
# DIAS:acquisitionMode                         x         x
# DIAS:acquisitionOrbitNumber                  x         x
# DIAS:archiveCollection                       x         x
# DIAS:archiveCreationTimeStamp                x         x
# DIAS:archiveInstanceReference                x         x
# DIAS:archiveProductURI                       x         x
# DIAS:archiveUpdateTimeStamp                  x         x
# DIAS:archivingCenter                         x         x
# DIAS:checksum                                x         x
# DIAS:closedSeaPercentage                     -         x
# DIAS:cloudCoverPercentage                    x         x
# DIAS:coastalCoverPercentage                  -         x
# DIAS:continentalIcePercentage                -         x
# DIAS:cycleNumber                             -         x
# DIAS:ecmwf                                   -         x
# DIAS:equivalentNumberofScene                 x         x
# DIAS:externalUrls                            x         x
# DIAS:footprint                               x         x
# DIAS:freshWaterCoverPercentage               -         x
# DIAS:imageFileFormat                         x         x
# DIAS:incidenceAngle                          x         x
# DIAS:ingestionDate                           x         x
# DIAS:jobId                                   x         x
# DIAS:landPercentage                          -         x
# DIAS:lastOrbitNumber                         -         x
# DIAS:lastRelativeOrbitNumber                 -         x
# DIAS:leapSecond                              -         x
# DIAS:leapSecondOccurrence                    -         x
# DIAS:lrmPercentage                           -         x
# DIAS:manualQualityCheckStatus                x         x
# DIAS:manualQualityCheckStatusComment         x         x
# DIAS:metadataFormat                          x         x
# DIAS:metadataURI                             x         x
# DIAS:onlineDate                              x         x
# DIAS:onlineStatus                            x         x
# DIAS:openSeaPercentage                       -         x
# DIAS:orbitDirection                          x         x
# DIAS:orderID                                 x         x
# DIAS:passDirection                           -         x
# DIAS:passNumber                              -         x
# DIAS:pduAlongTrackCoord                      -         x
# DIAS:pduDuration                             -         x
# DIAS:polarisation                            x         x
# DIAS:processingBaseline                      x         x
# DIAS:processingCenter                        x         x
# DIAS:processingDate                          x         x
# DIAS:productConfidentialityLevel             x         x
# DIAS:productDatapackSize                     x         x
# DIAS:productDeliveryFormat                   x         x
# DIAS:productLevel                            x         x
# DIAS:productMarkedForDeletion                x         x
# DIAS:productType                             x         x
# DIAS:qualityQuotes                           x         x
# DIAS:quickLookURI                            x         x
# DIAS:receivingStation                        x         x
# DIAS:referencePoint                          x         x
# DIAS:referenceProductOnly                    x         x
# DIAS:relativeOrbitDirection                  -         x
# DIAS:relativeOrbitNumber                     -         x
# DIAS:relativePassDirection                   -         x
# DIAS:relativePassNumber                      -         x
# DIAS:resolution                              x         x
# DIAS:salineWaterCoverPercentage              -         x
# DIAS:sarPercentage                           -         x
# DIAS:sceneIndex                              x         x
# DIAS:sensingStartDate                        x         x
# DIAS:sensingStopDate                         x         x
# DIAS:sensorFamily                            x         x
# DIAS:sensorMode                              x         x
# DIAS:snowCoverPercentage                     x         x
# DIAS:sourceStripID                           x         x
# DIAS:startOrbitNumber                        x         x
# DIAS:thumbnailURI                            x         x
# DIAS:tidalRegionCoverPercentage              -         x
# DIAS:timelinessCategory                      x         x
# DIAS:uuid                                    x         x
# DIAS:watcherRecordValidity                   x         x
# ows:BoundingBox                              x         x

# %% [markdown]
# ##### 'csw:Record' / 'DescribeRecord' - How to get all metadata (record elements) from given collection (step2) - here Sentinel1

# %%
d = {}
csw_S1 = c.getCollection("Sentinel1").mundi_csw()
d = csw_S1.mundidescriberecord()
csw_S1.url
# Out:
# 'https://mundiwebservices.com/acdc/catalog/proxy/search/Sentinel1/csw'

# %%
df = pd.DataFrame(d, index=['description'])
df.replace("\n","")
pd.set_option('max_colwidth', 200)
df.T
# Out:
#                                                                                                                                                                                                                                   description
# ows:BoundingBox                                                       The location of the two corners of the acquisition (using WGS-84 coordinates): Lower Left ie South west point (lon, lat) and Upper Right ie north East (lon, lat).  ...
# DIAS:uuid                                                                                                                                                                    external provider product identifier
# DIAS:sourceStripID                                                                                                                                                            Unique and efficient data strip id.
# DIAS:metadataFormat                                                                                                                                    This field sets the format of the catalogue file metadata.
# DIAS:imageFileFormat                                                                                                                                                         File format name of the image files.
# DIAS:orderID                                                                                                                                                                       Unique and efficient order id.
# DIAS:sceneIndex                                                                                                                                                            Scene number into acquisition segment.
# DIAS:metadataURI                                                                                                                                                                  A link to the feature metadata.
# DIAS:quickLookURI                                                                                                                                                                A link to the feature quicklook.
# DIAS:thumbnailURI                                                                                                                                                                A link to the feature thumbnail.
# DIAS:resolution                                                                                                                                                  The resolution of the image expressed in meters.
# DIAS:incidenceAngle                                                   Incidence angle of the acquisition, in degrees, between -90.0 and 90.0.                                In case of ground projected products, this value shall be set...
# DIAS:sensorFamily                                                                          The sensor family. Panchromatic sensors produce black and white images and multispectral sensors produce color images.
# DIAS:sensorMode                                                                                                                                                        Unified sensor code (native and combined).
# DIAS:orbitDirection                                                                                                                           Orbit direction during the acquisition (NA, Ascending, Descending).
# DIAS:acquisitionOrbitNumber                                                                                                                        \t\t                        Acquisition orbit number in the cycle.\t\t
# DIAS:polarisation                                                                                                                                                                     HH VV, HH/VV, HH/HV, VV/VH.
# DIAS:productType                                                                                                                                                                               GRD,SLC,OCN, IMAGE
# DIAS:productLevel                                                                                                                                                               The processing level of the image
# DIAS:archivingCenter                                                                               The UID of the Archiving Centers (see naming convention) holding the full-resolution image of the acquisition.
# DIAS:receivingStation                                                                                           The alphanumerical acronym of the station receiving the full-resolution image of the acquisition.
# DIAS:processingCenter                                                                                                               The alphanumerical acronym of the Processing Center that processed the image.
# DIAS:processingDate                                                                                                                                                           The processing date of the product.
# DIAS:footprint                                                                                                   The polygon representation (WKT format) of the acquisition footprint (using WGS-84 coordinates).
# DIAS:qualityQuotes                                                           Technical quality quotation of the acquisition (ex. “EGPU”), “E” stands for Excellent, “G” for Good, “P” for Poor, “U” for Unusable.
# DIAS:productConfidentialityLevel                                                                                                                                              Level of Confidence of the product.
# DIAS:equivalentNumberofScene                                                                                                                                       Number of equivalent scene inside the product.
# DIAS:productDatapackSize                                                                                                                              Size of the product datapack in archive in mega bytes (Mb).
# DIAS:acquisitionMode                                                                  Name of the image acquisition mode (Spot, Stereo, Tristereo, Surface, Frontier) can be deduced from the PDV link reference.
# DIAS:startOrbitNumber                                                                                                                                                                          Start orbit number
# DIAS:datatakeId                                                                                                                                                                                       datatake id
# DIAS:sliceNumber                                                                                                                                                                                     slice number
# DIAS:relativeOrbitNumber                                                                                                                                                                   Relative orbit (start)
# DIAS:lastOrbitNumber                                                                                                                                                                            Stop orbit number
# DIAS:lastRelativeOrbitNumber                                                                                                                                                           Stop relative orbit number
# DIAS:processingBaseline                                                                                                                                                                       processing baseline
# DIAS:archiveProductURI                                                                                                                                                Product localisation in archive collection.
# DIAS:archiveCollection                                                                                                                                                     Archive Collection (Data segregation).
# DIAS:productMarkedForDeletion                                                                          Product marked to be deleted. This attribute sets the list of location where the Product shall be deleted.
# DIAS:onlineStatus                                                                                                                                                           Product status (On-Line, Off-Line,…).
# DIAS:archiveInstanceReference                                                                                                Instance Identification (Actual Position of the product in archive system instance).
# DIAS:archiveCreationTimeStamp                                                                                                                                                   Product Creation Date in archive.
# DIAS:archiveUpdateTimeStamp                                                                                                                                                       Product Update Date in archive.
# DIAS:manualQualityCheckStatus                                                                                                                                              Image quality status manually checked.
# DIAS:manualQualityCheckStatusComment                                                                                           This string enables to give precision about the image manual quality check status.
# DIAS:referenceProductOnly                                                                                                                             Indicates if EO image data is available into local archive.
# DIAS:referencePoint                                                                                                                                                                              reference point.
# DIAS:jobId                                                                                                                                                                                                job id.
# DIAS:sensingStartDate                                                                                                                                                                     start acquisition date.
# DIAS:sensingStopDate                                                                                                                                                                        end acquisition date.
# DIAS:externalUrls                                                                                                                                                                    external download URls list.
# DIAS:watcherRecordValidity                                                                                                                                                                watcher record validity
# DIAS:timelinessCategory                                                                                                                                                                   watcher record validity
# DIAS:ingestionDate                                                                                                                                                       ingestion download date to DIAS storage.
# DIAS:onlineDate                                                                                                                                                product ready-to-use on line date in DIAS storage.
# DIAS:productDeliveryFormat                                                                                                                                        File format name which is proposed for download
# DIAS:checksum                                                                                                                                                             provider checksum of downloaded product

# %% [markdown]
# ##### 'csw:Record' / 'DescribeRecord' - How to get all metadata (record elements) from 'global' collections (step1)

# %%
csw = c.mundi_csw()
d = csw.mundidescriberecord()
csw.url
# Out:
# 'https://mundiwebservices.com/acdc/catalog/proxy/search/global/csw'

# %%
df = pd.DataFrame(d, index=['description'])
df.replace("\n","")
pd.set_option('max_colwidth', 200)
pd.set_option('display.max_rows',150)
df.T
# Out:
#                                                                                                                                                                                                                                     description
# ows:BoundingBox                                                         The location of the two corners of the acquisition (using WGS-84 coordinates): Lower Left ie South west point (lon, lat) and Upper Right ie north East (lon, lat).  ...
# DIAS:uuid                                                                                                                                                                      external provider product identifier
# DIAS:sourceStripID                                                                                                                                                              Unique and efficient data strip id.
# DIAS:metadataFormat                                                                                                                                      This field sets the format of the catalogue file metadata.
# DIAS:imageFileFormat                                                                                                                                                           File format name of the image files.
# DIAS:orderID                                                                                                                                                                         Unique and efficient order id.
# DIAS:sceneIndex                                                                                                                                                              Scene number into acquisition segment.
# DIAS:metadataURI                                                                                                                                                                    A link to the feature metadata.
# DIAS:quickLookURI                                                                                                                                                                  A link to the feature quicklook.
# DIAS:thumbnailURI                                                                                                                                                                  A link to the feature thumbnail.
# DIAS:resolution                                                                                                                                                    The resolution of the image expressed in meters.
# DIAS:incidenceAngle                                                     Incidence angle of the acquisition, in degrees, between -90.0 and 90.0.                                In case of ground projected products, this value shall be set...
# DIAS:sensorFamily                                                                            The sensor family. Panchromatic sensors produce black and white images and multispectral sensors produce color images.
# DIAS:sensorMode                                                                                                                                                          Unified sensor code (native and combined).
# DIAS:orbitDirection                                                                                                                             Orbit direction during the acquisition (NA, Ascending, Descending).
# DIAS:acquisitionOrbitNumber                                                                                                                          \t\t                        Acquisition orbit number in the cycle.\t\t
# DIAS:polarisation                                                                                                                                                                       HH VV, HH/VV, HH/HV, VV/VH.
# DIAS:productType                                                                                                                                                                                 GRD,SLC,OCN, IMAGE
# DIAS:productLevel                                                                                                                                                                 The processing level of the image
# DIAS:archivingCenter                                                                                 The UID of the Archiving Centers (see naming convention) holding the full-resolution image of the acquisition.
# DIAS:receivingStation                                                                                             The alphanumerical acronym of the station receiving the full-resolution image of the acquisition.
# DIAS:processingCenter                                                                                                                 The alphanumerical acronym of the Processing Center that processed the image.
# DIAS:processingDate                                                                                                                                                             The processing date of the product.
# DIAS:cloudCoverPercentage                                                                                                                                The cloud coverage percentage of the scene (or datastrip).
# DIAS:snowCoverPercentage                                                                                                                                  The snow coverage percentage of the scene (or datastrip).
# DIAS:footprint                                                                                                     The polygon representation (WKT format) of the acquisition footprint (using WGS-84 coordinates).
# DIAS:qualityQuotes                                                             Technical quality quotation of the acquisition (ex. “EGPU”), “E” stands for Excellent, “G” for Good, “P” for Poor, “U” for Unusable.
# DIAS:generalQuality                                                                                                                                                   General quality quotation of the acquisition.
# DIAS:sensorQuality                                                                                                                                                     Sensor quality quotation of the acquisition.
# DIAS:radiometricQuality                                                                                                                                           Radiometric quality quotation of the acquisition.
# DIAS:geometricQuality                                                                                                                                               Geometric quality quotation of the acquisition.
# DIAS:formatCorrectness                                                                                                                                               product format correctness of the acquisition.
# DIAS:productConfidentialityLevel                                                                                                                                                Level of Confidence of the product.
# DIAS:equivalentNumberofScene                                                                                                                                         Number of equivalent scene inside the product.
# DIAS:productDatapackSize                                                                                                                                Size of the product datapack in archive in mega bytes (Mb).
# DIAS:acquisitionMode                                                                    Name of the image acquisition mode (Spot, Stereo, Tristereo, Surface, Frontier) can be deduced from the PDV link reference.
# DIAS:startOrbitNumber                                                                                                                                                                            Start orbit number
# DIAS:datatakeId                                                                                                                                                                                         datatake id
# DIAS:sliceNumber                                                                                                                                                                                       slice number
# DIAS:tileIdentifier                                                                                                                                                                         product tile identifier
# DIAS:processingBaseline                                                                                                                                                                         processing baseline
# DIAS:highProbaCloudsPercentage                                                                                                                                                         High proba clouds percentage
# DIAS:mediumProbaCloudsPercentage                                                                                                                                                     Medium proba clouds percentage
# DIAS:notVegetatedPercentage                                                                                                                                                                Not vegetated percentage
# DIAS:unclassifiedPercentage                                                                                                                                                                 Unclassified percentage
# DIAS:vegetationPercentage                                                                                                                                                                     Vegetation percentage
# DIAS:waterPercentage                                                                                                                                                                               Water percentage
# DIAS:aotRetreivalAccuracy                                                                                                                                                                    Aot retrieval accuracy
# DIAS:cloudShadowPercentage                                                                                                                                                                  Cloud shadow percentage
# DIAS:darkFeaturesPercentage                                                                                                                                                                Dark features percentage
# DIAS:nodataPixelPercentage                                                                                                                                                                 No data pixel percentage
# DIAS:radiativeTransferAccuracy                                                                                                                                                          Radiative transfer accuracy
# DIAS:saturatedDefectivePixelPercentage                                                                                                                                         Saturated defective pixel percentage
# DIAS:thinCirrusPercentage                                                                                                                                                                   Thin cirrus percentage
# DIAS:waterVapourRetrievalAccuracy                                                                                                                                                   Water Vapour Retrieval Accuracy
# DIAS:cycleNumber                                                                                                                                                                                       cycle Number
# DIAS:ecmwf                                                                                                                                                                                              Ecmwf type
# DIAS:pduDuration                                                                                                                                                                                   PDU Duration (s)
# DIAS:passNumber                                                                                                                                                                                   Pass Start number
# DIAS:passDirection                                                                                                                                                                           Pass direction (start)
# DIAS:relativeOrbitDirection                                                                                                                                                        Relative Orbit Direction (start)
# DIAS:relativeOrbitNumber                                                                                                                                                                     Relative orbit (start)
# DIAS:lastOrbitNumber                                                                                                                                                                              Stop orbit number
# DIAS:lastRelativeOrbitNumber                                                                                                                                                             Stop relative orbit number
# DIAS:relativePassNumber                                                                                                                                                                       Relative pass (start)
# DIAS:relativePassDirection                                                                                                                                                          Relative pass direction (start)
# DIAS:pduAlongTrackCoord                                                                                                                                                              PDU Along Track Coordinate (s)
# DIAS:coastalCoverPercentage                                                                                                                                                            Coastal Cover Percentage (%)
# DIAS:freshWaterCoverPercentage                                                                                                                                              Fresh Inland Water Cover Percentage (%)
# DIAS:salineWaterCoverPercentage                                                                                                                                                   Saline Water Cover Percentage (%)
# DIAS:tidalRegionCoverPercentage                                                                                                                                                   Tidal Region Cover Percentage (%)
# DIAS:landPercentage                                                                                                                                                                 Measurement Records on Land (%)
# DIAS:closedSeaPercentage                                                                                                                                                      Measurement Records on Closed Sea (%)
# DIAS:continentalIcePercentage                                                                                                                                            Measurement Records on Continental Ice (%)
# DIAS:openSeaPercentage                                                                                                                                                        Measurement Records on Open Ocean (%)
# DIAS:lrmPercentage                                                                                                                                                              Measurement Records in LRM Mode (%)
# DIAS:sarPercentage                                                                                                                                                              Measurement Records in SAR Mode (%)
# DIAS:leapSecond                                                                                                                                                                                     Leap Second (s)
# DIAS:leapSecondOccurrence                                                                                                                                                                    Leap Second Occurrence
# DIAS:archiveProductURI                                                                                                                                                  Product localisation in archive collection.
# DIAS:archiveCollection                                                                                                                                                       Archive Collection (Data segregation).
# DIAS:productMarkedForDeletion                                                                            Product marked to be deleted. This attribute sets the list of location where the Product shall be deleted.
# DIAS:onlineStatus                                                                                                                                                             Product status (On-Line, Off-Line,…).
# DIAS:archiveInstanceReference                                                                                                  Instance Identification (Actual Position of the product in archive system instance).
# DIAS:archiveCreationTimeStamp                                                                                                                                                     Product Creation Date in archive.
# DIAS:archiveUpdateTimeStamp                                                                                                                                                         Product Update Date in archive.
# DIAS:manualQualityCheckStatus                                                                                                                                                Image quality status manually checked.
# DIAS:manualQualityCheckStatusComment                                                                                             This string enables to give precision about the image manual quality check status.
# DIAS:referenceProductOnly                                                                                                                               Indicates if EO image data is available into local archive.
# DIAS:referencePoint                                                                                                                                                                                reference point.
# DIAS:jobId                                                                                                                                                                                                  job id.
# DIAS:sensingStartDate                                                                                                                                                                       start acquisition date.
# DIAS:sensingStopDate                                                                                                                                                                          end acquisition date.
# DIAS:externalUrls                                                                                                                                                                      external download URls list.
# DIAS:watcherRecordValidity                                                                                                                                                                  watcher record validity
# DIAS:timelinessCategory                                                                                                                                                                     watcher record validity
# DIAS:ingestionDate                                                                                                                                                         ingestion download date to DIAS storage.
# DIAS:onlineDate                                                                                                                                                  product ready-to-use on line date in DIAS storage.
# DIAS:productDeliveryFormat                                                                                                                                          File format name which is proposed for download
# DIAS:checksum                                                                                                                                                               provider checksum of downloaded product
# DIAS:geometricShiftEasting                                                                                                                                                              geometric shift to the East
# DIAS:geometricShiftNorthing                                                                                                                                                            geometric shift to the North
# DIAS:geometricShiftReference                                                                                                                                                              geometric shift reference
# DIAS:clearSkyPercentage                                                                                                                                                                        clear sky percentage
# DIAS:cloudProcessingStatus                                                                                                                                                         cloud coverage processing status
# DIAS:geometryProcessingStatus                                                                                                                                                            geometry processing status
# DIAS:cloudCoverageProcessingTimestamp                                                                                                                                           cloud coverage processing timestamp
# DIAS:geometryProcessingTimestamp                                                                                                                                                      geometry processing timestamp
# DIAS:sceneIdentifier                                                                                                                                                                               scene identifier
# DIAS:dayNightIndicator                                                                                                                                                                          day/night indicator
# DIAS:collectionNumber                                                                                                                                                                             collection number
# DIAS:wrsPath                                                                                                                                                             Worldwide Reference System satellite track
# DIAS:wrsRow                                                                                                                                                                Worldwide Reference System satellite row
# DIAS:dateL1Generated                                                                                                                                                                             L1 generation date
# DIAS:sceneCloudCover                                                                                                                                                                scene cloud coverage percentage
# DIAS:geometricRMSEModelMeters                                                                                   Combined RMSE (Root Mean Square Error) of the geometric residuals (meters) in both track directions
# DIAS:dataAnomaly                                                                                                                                                            Sensor specific data correction missing
# DIAS:scanLineCorrector                                                                                                                                                           Sensor scan line correction on/off
# DIAS:nadir                                                                                                                                                                          nadir or side-track acquisition
